# %% [markdown]
# ### Different Types of Joins

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Left join, Right Join, Inner Join, Left Only join, Right Onlly join,Full outer join, Full outer join only

# %% [markdown]
# impo

# %%
import pandas as pd

# %%
df_orders = pd.read_csv("orders.csv")

# %%
df_orders.head(10)
# Out:
#            Order Id        Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB  2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM  2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L  2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ  2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E  2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# 5  AT0R4DFYYAFOC88Q  2014-07-21  W48JPR1UYWJ18NC6  LJKS5NK6788CYMUU
# 6  2DDN2LHS7G85GKPQ  2014-04-29  1MKLAKBOE3SP7YUL  LJKS5NK6788CYMUU
# 7  FM608JK1N01BPUQN  2014-05-08  E8WJZ1FOSKZD2MJN  36MFTZOYMTAJP1RK
# 8  CK331XXNIBQT81QL  2015-05-23  CTZSFFKQTY7SBZ4J  36MFTZOYMTAJP1RK
# 9  FESGKOQN2OZZWXY3  2016-01-10  US0NQYNNHS1SQJ4S  36MFTZOYMTAJP1RK
#
#                 Date of Meal  \
# 0  2016-05-31 07:00:00+02:00
# 1  2018-10-01 20:00:00+02:00
# 2  2014-08-23 14:00:00+02:00
# 3  2014-04-07 21:00:00+02:00
# 4  2015-07-27 14:00:00+02:00
# 5  2014-07-17 20:00:00+02:00
# ...

# %%
df_orders.shape
# Out:
# (14362, 9)

# %% [markdown]
# ## Adding rows or Combining dataframes

# %%
new_row = {'Order Id':'3224frefdsfd3r24',
           'Date':'2016-04-22',
           'Meal Id':'In423fdsfsf'}

# %%
df_test = df_orders.copy()

# %%
df_test = df_test.append(new_row,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36588\1648181180.py in ?()
# ----> 1 df_test = df_test.append(new_row,ignore_index=True)
#
# c:\Users\sanja\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
pd?
# Out:
# Type:        module
# String form: <module 'pandas' from 'c:\\Users\\sanja\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>
# File:        c:\users\sanja\anaconda3\lib\site-packages\pandas\__init__.py
# Docstring:
# pandas - a powerful data analysis and manipulation library for Python
# ...
#
# **pandas** is a Python package providing fast, flexible, and expressive data
# structures designed to make working with "relational" or "labeled" data both
# easy and intuitive. It aims to be the fundamental high-level building block for
# doing practical, **real world** data analysis in Python. Additionally, it has
# the broader goal of becoming **the most powerful and flexible open source data
# analysis / manipulation tool available in any language**. It is already well on
# its way toward this goal.
#
# Main Features
# -------------
# Here are just a few of the things that pandas does well:
#
#   - Easy handling of missing data in floating point as well as non-floating
#     point data.
# ...

# %%
print(pd.__version__)
# Out:
# 2.0.3

# %%
df_test = pd.concat([df_test, pd.DataFrame([new_row])], ignore_index=True)

# %%
df_test.shape
# Out:
# (14363, 9)

# %%
df_test.tail(5)
# Out:
#                Order Id        Date           Meal Id        Company Id  \
# 14358  RFK2C21CD7IAOUZT  2016-06-30  EGQRRRN5D1Y97WGD  I27J9NPYES4BIXBR
# 14359  2UMDU938DTE7D808  2016-04-10  AV323CBF7N78MCYD  I27J9NPYES4BIXBR
# 14360  NEER4D5TN6GQV9WA  2015-07-19  RDLHP30JLO9RYWDR  I27J9NPYES4BIXBR
# 14361  2NF38UES2LW6TR2A  2017-02-24  MOEZTCDKASD8Z0UP                 I
# 14362  3224frefdsfd3r24  2016-04-22       In423fdsfsf               NaN
#
#                     Date of Meal                              Participants  \
# 14358  2016-06-26 20:00:00+02:00                       ['Kenisha Ordonez']
# 14359  2016-04-10 07:00:00+02:00                    ['Douglas Villanueva']
# 14360  2015-07-21 09:00:00+02:00  ['Douglas Villanueva' 'Kenisha Ordonez']
# 14361                        NaN                                       NaN
# 14362                        NaN                                       NaN
#
#        Meal Price Type of Meal Heroes Adjustment
# ...

# %%
df_new_withoutignore = pd.concat([df_orders, df_test])

# %%
df_new_withoutignore
# Out:
#                Order Id        Date           Meal Id        Company Id  \
# 0      839FKFW2LLX4LMBB  2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1      97OX39BGVMHODLJM  2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      041ORQM5OIHTIU6L  2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      YT796QI18WNGZ7ZJ  2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      6YLROQT27B6HRF4E  2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# ...                 ...         ...               ...               ...
# 14358  RFK2C21CD7IAOUZT  2016-06-30  EGQRRRN5D1Y97WGD  I27J9NPYES4BIXBR
# 14359  2UMDU938DTE7D808  2016-04-10  AV323CBF7N78MCYD  I27J9NPYES4BIXBR
# 14360  NEER4D5TN6GQV9WA  2015-07-19  RDLHP30JLO9RYWDR  I27J9NPYES4BIXBR
# 14361  2NF38UES2LW6TR2A  2017-02-24  MOEZTCDKASD8Z0UP                 I
# 14362  3224frefdsfd3r24  2016-04-22       In423fdsfsf               NaN
#
#                     Date of Meal                              Participants  \
# ...

# %%
df_new_withoutignore_col = pd.concat([df_orders, df_test], axis=1)

# %%
df_new_withoutignore_col.shape
# Out:
# (14363, 18)

# %% [markdown]
# ## Merge

# %%
df_order_leads = pd.read_csv("order_leads.csv")

# %%
df_sales_team = pd.read_csv("sales_team.csv")

# %%
df_order_leads.head
# Out:
# <bound method NDFrame.head of                Order Id        Company Id            Company Name        Date  \
# 0      80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2017-02-18
# 1      TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2015-07-30
# 2      839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2016-05-27
# 3      97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2018-09-27
# 4      5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2016-01-14
# ...                 ...               ...                     ...         ...
# 26850  RHWPAUYMZAUR4790  LF85GK2DBRYS10ZA            Watery Barge  2015-05-04
# 26851  DRAQ8KY395S62DUI  LF85GK2DBRYS10ZA            Watery Barge  2015-10-02
# 26852  7ZU10X0S71A9ISB2  LF85GK2DBRYS10ZA            Watery Barge  2014-11-17
# 26853  FQFTQEKQ4D7JYS8K  LF85GK2DBRYS10ZA            Watery Barge  2017-05-08
# 26854               R9W               NaN                     NaN         NaN
#
# ...

# %%
df_sales_team.head
# Out:
# <bound method NDFrame.head of               Sales Rep      Sales Rep Id                    Company Name  \
# 0     Jessie Mcallister  97UNNAT790E0WM4N          Chimera-Chasing Casbah
# 1     Jessie Mcallister  97UNNAT790E0WM4N                Tangential Sheds
# 2     Jessie Mcallister  97UNNAT790E0WM4N                   Two-Mile Grab
# 3     Jessie Mcallister  97UNNAT790E0WM4N  Three-Men-And-A-Helper Congo'S
# 4     Jessie Mcallister  97UNNAT790E0WM4N        Biophysical Battleground
# ...                 ...               ...                             ...
# 4720      Joel Woodbury  YBWRC1WQHXE895WV          Jammed-Together Stable
# 4721      Joel Woodbury  YBWRC1WQHXE895WV               Laureate Barbital
# 4722    Hazel Dickerson  NIW73ZQMGEOB7BHT                 Spotty Adoniram
# 4723    Hazel Dickerson  NIW73ZQMGEOB7BHT      Physicochemical Impatience
# 4724    Hazel Dickerson  NIW73ZQMGEOB7BHT             Fierce Productivity
#
#             Company Id
# 0     LJKS5NK6788CYMUU
# ...

# %%
df_order_leads
# Out:
#                Order Id        Company Id            Company Name        Date  \
# 0      80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2017-02-18
# 1      TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2015-07-30
# 2      839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2016-05-27
# 3      97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2018-09-27
# 4      5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  2016-01-14
# ...                 ...               ...                     ...         ...
# 26850  RHWPAUYMZAUR4790  LF85GK2DBRYS10ZA            Watery Barge  2015-05-04
# 26851  DRAQ8KY395S62DUI  LF85GK2DBRYS10ZA            Watery Barge  2015-10-02
# 26852  7ZU10X0S71A9ISB2  LF85GK2DBRYS10ZA            Watery Barge  2014-11-17
# 26853  FQFTQEKQ4D7JYS8K  LF85GK2DBRYS10ZA            Watery Barge  2017-05-08
# 26854               R9W               NaN                     NaN         NaN
#
#        Order Value  Converted
# ...

# %%
df_sales_team
# Out:
#               Sales Rep      Sales Rep Id                    Company Name  \
# 0     Jessie Mcallister  97UNNAT790E0WM4N          Chimera-Chasing Casbah
# 1     Jessie Mcallister  97UNNAT790E0WM4N                Tangential Sheds
# 2     Jessie Mcallister  97UNNAT790E0WM4N                   Two-Mile Grab
# 3     Jessie Mcallister  97UNNAT790E0WM4N  Three-Men-And-A-Helper Congo'S
# 4     Jessie Mcallister  97UNNAT790E0WM4N        Biophysical Battleground
# ...                 ...               ...                             ...
# 4720      Joel Woodbury  YBWRC1WQHXE895WV          Jammed-Together Stable
# 4721      Joel Woodbury  YBWRC1WQHXE895WV               Laureate Barbital
# 4722    Hazel Dickerson  NIW73ZQMGEOB7BHT                 Spotty Adoniram
# 4723    Hazel Dickerson  NIW73ZQMGEOB7BHT      Physicochemical Impatience
# 4724    Hazel Dickerson  NIW73ZQMGEOB7BHT             Fierce Productivity
#
#             Company Id
# 0     LJKS5NK6788CYMUU
# 1     36MFTZOYMTAJP1RK
# ...

# %%
df_orders
# Out:
#                Order Id        Date           Meal Id        Company Id  \
# 0      839FKFW2LLX4LMBB  2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1      97OX39BGVMHODLJM  2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      041ORQM5OIHTIU6L  2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      YT796QI18WNGZ7ZJ  2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      6YLROQT27B6HRF4E  2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# ...                 ...         ...               ...               ...
# 14357  BD2DKH8I61Y0NL7Z  2018-01-12  4VLH5HYF70RP1YJK  I27J9NPYES4BIXBR
# 14358  RFK2C21CD7IAOUZT  2016-06-30  EGQRRRN5D1Y97WGD  I27J9NPYES4BIXBR
# 14359  2UMDU938DTE7D808  2016-04-10  AV323CBF7N78MCYD  I27J9NPYES4BIXBR
# 14360  NEER4D5TN6GQV9WA  2015-07-19  RDLHP30JLO9RYWDR  I27J9NPYES4BIXBR
# 14361  2NF38UES2LW6TR2A  2017-02-24  MOEZTCDKASD8Z0UP                 I
#
#                     Date of Meal                              Participants  \
# ...

# %%
pd.merge(df_orders, df_order_leads, on='Order Id')
# Out:
#                Order Id      Date_x           Meal Id      Company Id_x  \
# 0      839FKFW2LLX4LMBB  2016-05-27  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1      97OX39BGVMHODLJM  2018-09-27  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2      041ORQM5OIHTIU6L  2014-08-24  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3      YT796QI18WNGZ7ZJ  2014-04-12  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4      6YLROQT27B6HRF4E  2015-07-28  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
# ...                 ...         ...               ...               ...
# 13381  344K78BVPMQ3UKX4  2017-05-15  S30KDKX1JA90MV7G  I9SNN0NI7ETOAN9C
# 13382  KWIAJ8L4YW5SZWZG  2018-07-17  23YSFGABUPN92QIS  I9SNN0NI7ETOAN9C
# 13383  4BG0QG7Z0GP2VLHJ  2014-07-14  GRDNQR5P1CCT6NIP  LF85GK2DBRYS10ZA
# 13384  RHWPAUYMZAUR4790  2015-05-04  49KFEY8GRRWND4T2  LF85GK2DBRYS10ZA
# 13385  7ZU10X0S71A9ISB2  2014-11-17  XZGW93T06NGWCWSP  LF85GK2DBRYS10ZA
#
#                     Date of Meal  \
# 0      2016-05-31 07:00:00+02:00
# ...

# %%
df_order_leads.shape
# Out:
# (26855, 6)

# %%
df_orders.shape
# Out:
# (14362, 9)

# %%
df_orders.columns
# Out:
# Index(['Order Id', 'Date', 'Meal Id', 'Company Id', 'Date of Meal',
#        'Participants', 'Meal Price', 'Type of Meal', 'Heroes Adjustment'],
#       dtype='object')

# %%
pd.merge(df_orders[['Order Id','Meal Id','Participants']],
        df_order_leads.rename(columns = {'Order Id':"Alternate Id"}),
        left_on = 'Order Id',
        right_on = 'Alternate Id')
# Out:
#                Order Id           Meal Id  \
# 0      839FKFW2LLX4LMBB  INBUX904GIHI8YBD
# 1      97OX39BGVMHODLJM  J0MMOOPP709DIDIE
# 2      041ORQM5OIHTIU6L  E4UJLQNCI16UX5CS
# 3      YT796QI18WNGZ7ZJ  C9SDFHF7553BE247
# 4      6YLROQT27B6HRF4E  48EQXS6IHYNZDDZ5
# ...                 ...               ...
# 13381  344K78BVPMQ3UKX4  S30KDKX1JA90MV7G
# 13382  KWIAJ8L4YW5SZWZG  23YSFGABUPN92QIS
# 13383  4BG0QG7Z0GP2VLHJ  GRDNQR5P1CCT6NIP
# 13384  RHWPAUYMZAUR4790  49KFEY8GRRWND4T2
# 13385  7ZU10X0S71A9ISB2  XZGW93T06NGWCWSP
#
#                                             Participants      Alternate Id  \
# 0                                       ['David Bishop']  839FKFW2LLX4LMBB
# 1                                       ['David Bishop']  97OX39BGVMHODLJM
# 2                                     ['Karen Stansell']  041ORQM5OIHTIU6L
# 3                                       ['Addie Patino']  YT796QI18WNGZ7ZJ
# 4                      ['Addie Patino' 'Susan Guerrero']  6YLROQT27B6HRF4E
# ...

# %%
# if i want to find the avg of MEal price, also for each type of meal,  also per date
df_orders.groupby(['Type of Meal'])['Meal Price'].agg('mean')
# Out:
# Type of Meal
# Breakfast    405.021192
# Dinner       400.078177
# Lunch        407.196124
# Name: Meal Price, dtype: float64

# %% [markdown]
# ### Humble intro to Preprocessing

# %%
df_orders['Date of Meal']=pd.to_datetime(df_orders['Date of Meal'], utc= True)

# %%
df_orders['Date of Meal']=df_orders['Date of Meal'].dt.date

# %% [markdown]
# ### Descriptive statistics

# %%
df_orders.groupby(['Date of Meal', 'Type of Meal','Heroes Adjustment'])['Meal Price'].agg('mean')
# Out:
# Date of Meal  Type of Meal  Heroes Adjustment
# 2013-12-29    Breakfast     False                516.00
#               Dinner        False                 37.00
#               Lunch         False                451.00
# 2013-12-30    Breakfast     False                 67.00
#               Dinner        False                338.00
#                                                   ...
# 2018-12-31    Dinner        False                514.00
# 2019-01-01    Dinner        False                523.75
# 2019-01-02    Breakfast     False                187.00
#               Dinner        False                723.00
# 2019-01-04    Lunch         False                606.00
# Name: Meal Price, Length: 5217, dtype: float64

# %%
df_orders.pivot?
# Out:
# Signature:
# df_orders.pivot(
#     *,
#     columns,
#     index=typing.Literal[<no_default>],
#     values=typing.Literal[<no_default>],
# ) -> 'DataFrame'
# Docstring:
# Return reshaped DataFrame organized by given index / column values.
#
# Reshape data (produce a "pivot" table) based on column values. Uses
# unique values from specified `index` / `columns` to form axes of the
# resulting DataFrame. This function does not support data
# aggregation, multiple values will result in a MultiIndex in the
# columns. See the :ref:`User Guide <reshaping>` for more on reshaping.
#
# Parameters
# ----------
# columns : str or object or a list of str
#     Column to use to make new frame's columns.
#
#     .. versionchanged:: 1.1.0
#        Also accept list of columns names.
#
# index : str or object or a list of str, optional
#     Column to use to make new frame's index. If not given, uses existing index.
#
#     .. versionchanged:: 1.1.0
#        Also accept list of index names.
#
# ...

# %%
import numpy as np

# %%
df_orders.pivot(index =['Date of Meal', 'Type of Meal','Heroes Adjustment'], values = "Meal Price",aggfunc=np.mean, margins =True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df_orders.pivot(index =['Date of Meal', 'Type of Meal','Heroes Adjustment'], values = "Meal Price",aggfunc=np.mean, margins =True)
#
# TypeError: DataFrame.pivot() got an unexpected keyword argument 'aggfunc'

# %%
pd.pivot_table(df_orders,index = ['Type of Meal','Meal Id'], values = 'Meal Price',aggfunc = np.mean,margins = True).loc['Breakfast']
# Out:
#                   Meal Price
# Meal Id
# 001DCDCE6S200FA9        52.0
# 003BA2DZAP6W2G2E        75.0
# 006R11Z6EG7B3P4E       163.0
# 00CWGA8NET6JVK8F        18.0
# 00IQ0SHRBHGD1PXN       259.0
# ...                      ...
# ZYQRUJSAY8PBS21A       646.0
# ZYRCW2PKTHPX6H75       186.0
# ZZ41JUW2PQWKCS9I       667.0
# ZZU2TIJM9THZHLS9       597.0
# ZZWQS5JPVSA6JOBF       697.0
#
# [4766 rows x 1 columns]
